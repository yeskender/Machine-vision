# %%
#Construct a histogram of the brightness of the image. 
#Apply the operation "linear stretching of brightness" and "the gray world" to the image. 
#Operation "the gray world" needs to be realized independently. 
#The mean can be called three times.
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('mv.png')
color = ('b','g','r')

plt.subplot(121)
plt.imshow(img,cmap='gray')
plt.show()
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[596],[0,596])
    plt.plot(histr,color = col)
    plt.xlim([0,596])
plt.show()

hist,bins = np.histogram(img.flatten(),596,[0,596])

plt.hist(img.flatten(),596,[0,596], color = 'r')
plt.xlim([0,596])
plt.legend(('histogram'), loc = 'upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
#import matplotlib.image as img
import numpy as np
import scipy.misc as img
from skimage import feature

from scipy import ndimage
import random
# %matplotlib inline


image = img.imread('./dd.jpg')
imag = img.imread('./dd.jpg', mode = 'F')
im = image


fig = plt.figure(figsize=(15,10))

plt.subplot(223)
plt.imshow(image)

plt.subplot(221)
plt.hist(im.ravel(), 256, [0,256])


sumr = 0
sumg = 0
sumb = 0
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        sumr += image[i,j,0]
        sumg += image[i,j,1]
        sumb += image[i,j,2]

sumr /= image.size
sumg /= image.size
sumb /= image.size

avg = sumr + sumg + sumb
avg /= 3


for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        image[i,j,0]*=avg/sumr
        image[i,j,1]*=avg/sumg
        image[i,j,2]*=avg/sumb
                

plt.subplot(222)
plt.imshow(image)



plt.show()

# %%
import numpy as np
from skimage import data
img = data.camera()
values, bins = np.histogram(image2, bins=np.arange(256))
fig, ax1 = plt.subplots(figsize=(8, 4))
ax1.plot(bins[:-1], values, lw=2, c='k')
ax1.set_xlim(xmax=256)
ax1.set_yticks([0, 400])
ax1.set_aspect(.2)
ax1.set_title('Histogram', fontsize=24)
